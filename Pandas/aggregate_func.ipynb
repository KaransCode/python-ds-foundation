# %%
import pandas as pd

# %% [markdown]
# Aggregate Function :-Reduces a set of values into a single summary value Used to summarize and analyze data Often used with the groupby() function

# %%
# Loading Dataset
poke_data = pd.read_csv("pokemon.csv")
print(poke_data)

# %%
# Finding Mean of numeric column

# Mean - Average value of a column
poke_avg = poke_data.mean(numeric_only=True)
# print(poke_avg)

# Min. value of the data of a column
# print(poke_data.min(numeric_only=True))

# Max. value of the data of a column
# print(poke_data.max(numeric_only=True))

# Count value of the data of a column
print(poke_data.count())

# %%
# Single column
# print(poke_data["Height"] . mean())
# print (poke_data["Height" ].sum())
# print(poke_data["Height"].min())
# print(poke_data["Height"].max())
# print(poke_data["Height"].count())

# %%
# Grouping
group = poke_data.groupby("Type2")
print(group["Height"].mean())
