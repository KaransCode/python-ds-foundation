# %%
import pandas as pd

# %%
data = pd.read_csv('raw_grades.csv')

print(data)

passed = data[data["Score"] >= 40]

print(passed)

passed.to_csv("passed_students.csv", index=True)
# Out:
#    Student  Score
# 0    Alice     35
# 1      Bob     45
# 2  Charlie     20
# 3     Dave     40
#   Student  Score
# 1     Bob     45
# 3    Dave     40
