# %% [markdown]
# Working with csv files

# %%
import pandas as pd

# %%
poke_df = pd.read_csv("pokemon.csv")
# print(poke_pokemon_df.head()) # 1st 5 rows
# print(poke_df.tail()) # last 5 rows

# print(poke_df.to_string()) # to print complete df

# %%
pokemon_df = pd.read_csv("pokemon.csv", index_col=["Name"])
# print(pokemon_df)
# print(pokemon_df.loc["Pikachu"])

poke_name = input("Enter a Pokemon Name :")

try:
    print(pokemon_df.loc[poke_name])
except KeyError:
    print(f"{poke_name} doesn't exists.")
# Out:
# Meuw doesn't exists.

# %%
# SELECTION BY COLUMN
# print(pokemon_df["Name"].to_string())
# print(pokemon_df["Height" ].to_string())
# print(pokemon_df["Weight" ].to_string())
# print(pokemon_df[["Height", "Weight"]].to_string())

# %%
# SELECTION BY ROW/S
# using loc
# print(pokemon_df.loc["Charizard":"Blastoise" ,["Height" ,"Weight"]])

lgnd = pokemon_df["Legendary"] > 0
print(pokemon_df[lgnd])

# using iloc
# print(pokemon_df.iloc[0:12])
# print(pokemon_df.iloc[0:12:2, 3:])
